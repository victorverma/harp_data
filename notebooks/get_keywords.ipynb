# %%
import drms
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 2024-09-26 20:12:22 - numexpr.utils - INFO: NumExpr defaulting to 8 threads.

# %% [markdown]
# The code below that obtains metadata is based on (1), which documents the `drms` package.
#
# - (1) https://docs.sunpy.org/projects/drms/en/stable/
#
# Some other useful references are listed below. (2) has several code examples. (3) has lots of information about the data produced by the Solar Dynamics Observatory (SDO), how it is organized, how to access it, and how to process it. Section 4.2.2 ("Selecting Records") of (3) explains how to construct the queries that are used below. (4) has general information about the SHARP parameters; (5) gives the meanings of the bits of the QUALITY keyword. (6) and (7) are papers on the pipeline that creates data from the SDO's Helioseismic and Magnetic Imager (HMI), including the SHARP parameter data.
#
# - (2) https://github.com/sunpy/drms/tree/main/examples
# - (3) https://www.lmsal.com/sdodocs/doc/dcur/SDOD0060.zip/zip/entry/
# - (4) http://jsoc.stanford.edu/doc/data/hmi/sharp/sharp.htm
# - (5) http://jsoc.stanford.edu/jsocwiki/Lev1qualBits
# - (6) https://doi.org/10.1007/s11207-014-0529-3
# - (7) https://doi.org/10.1007/s11207-014-0516-8

# %%
cli = drms.Client()

# %% [markdown]
# There are several SHARP parameter series; `cea` series correct for the distortion that occurs when representing the 3D Sun in 2D, `dconS` series correct for scattered light, and `nrt` series contain near-real time data. We use `cea` series on the suggestion of Ward Manchester. For purposes of comparison, we also use `nrt` data; use of definitive data is recommended on page 3565 of (6). All available data series can be viewed using the `series()` method, which lists data series matching a given regular expression. For example, we can display all the SHARP parameter data series:

# %%
cli.series(regex="hmi\\.sharp")
# Out:
# ['hmi.sharp_720s',
#  'hmi.sharp_720s_dconS',
#  'hmi.sharp_720s_nrt',
#  'hmi.sharp_cea_720s',
#  'hmi.sharp_cea_720s_dconS',
#  'hmi.sharp_cea_720s_nrt']

# %% [markdown]
# The `info()` method of the `Client` class creates an object with information about a data series. For example, we can verify that the primary keys of the series are `HARPNUM` and `T_REC` as follows:

# %%
cli.info("hmi.sharp_cea_720s").primekeys
# Out:
# ['HARPNUM', 'T_REC']

# %% [markdown]
# We next get all the keywords, their descriptions, and their data types for the definitive and `nrt` `cea` series:

# %%
keywords_cea = cli.info("hmi.sharp_cea_720s").keywords
keywords_cea_nrt = cli.info("hmi.sharp_cea_720s_nrt").keywords

# %% [markdown]
# In both data frames, each entry in the `linkinfo` column is `None`.

# %%
print(
    keywords_cea["linkinfo"].apply(lambda x: x is None).all(),
    keywords_cea_nrt["linkinfo"].apply(lambda x: x is None).all()
)
# Out:
# True True

# %% [markdown]
# Get rid of the `linkinfo` columns.

# %%
keywords_cea.drop("linkinfo", axis=1, inplace=True)
keywords_cea_nrt.drop("linkinfo", axis=1, inplace=True)

# %% [markdown]
# Identify the keywords that are in both data frames; of those, identify the ones with different information in the two data frames.

# %%
common_keywords = keywords_cea.index.intersection(keywords_cea_nrt.index)
keywords_cea_ = keywords_cea.loc[common_keywords]
keywords_cea_nrt_ = keywords_cea_nrt.loc[common_keywords]
comparison = keywords_cea_.eq(keywords_cea_nrt_)
keywords_w_diffs = comparison[~comparison.all(axis=1)].index

# %% [markdown]
# Insert columns with the series names to make comparison easier.

# %%
keywords_cea.insert(0, "series", "cea")
keywords_cea_nrt.insert(0, "series", "cea_nrt")

# %% [markdown]
# There are few keywords with differences, and those differences are minor, though some seem strange. For example, the definitions of `INVVLAVE` are different.

# %%
pd.concat([
    keywords_cea.loc[keywords_w_diffs],
    keywords_cea_nrt.loc[keywords_w_diffs]
])
# Out:
#            series    type  recscope                     defval     units  \
# name
# WCSNAME       cea  string  constant    Carrington Heliographic      none
# INVVLAVE      cea  double  variable                        nan   Maxwell
# INVBLAVE      cea  double  variable                        nan  Gauss/Mm
# INVNPRCS      cea     int  variable                         -1    number
# WCSNAME   cea_nrt  string  constant  Helioprojective-cartesian      none
# INVVLAVE  cea_nrt  double  variable                        nan      cm/s
# INVBLAVE  cea_nrt  double  variable                        nan     gauss
# INVNPRCS  cea_nrt     int  variable                         -1      none
#
#                                                        note  is_time  \
# name
# WCSNAME                                     WCS system name    False
# INVVLAVE                      [USFLUXL] Total unsigned flux    False
# INVBLAVE  [MEANGBL] Mean value of the line-of-sight fiel...    False
# INVNPRCS  [CMASKL] Number of pixels that contributed to ...    False
# WCSNAME                                     WCS system name    False
# INVVLAVE    avarage of inverted V_los over processed pixels    False
# INVBLAVE    avarage of inverted B_los over processed pixels    False
# INVNPRCS                          Numer of pixels processed    False
#
#           is_integer  is_real  is_numeric
# name
# WCSNAME        False    False       False
# INVVLAVE       False     True        True
# INVBLAVE       False     True        True
# INVNPRCS        True    False        True
# WCSNAME        False    False       False
# INVVLAVE       False     True        True
# INVBLAVE       False     True        True
# INVNPRCS        True    False        True

# %% [markdown]
# Every keyword in the `nrt` `cea` data is also in the `cea` data.

# %%
keywords_cea_nrt.index.difference(keywords_cea.index)
# Out:
# Index([], dtype='object', name='name')

# %% [markdown]
# We examine the keywords that are in both series.

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
keywords_cea_
# Out:
#                           type  recscope                    defval  \
# name
# cparms_sg000            string  variable             compress Rice
# magnetogram_bzero       double  variable                         0
# magnetogram_bscale      double  variable                       0.1
# cparms_sg001            string  variable
# bitmap_bzero            double  variable                         0
# bitmap_bscale           double  variable                         1
# cparms_sg002            string  variable             compress Rice
# Dopplergram_bzero       double  variable                         0
# Dopplergram_bscale      double  variable                       0.5
# cparms_sg003            string  variable             compress Rice
# continuum_bzero         double  variable                     97304
# continuum_bscale        double  variable                         3
# cparms_sg004            string  variable             compress Rice
# Bp_bzero                double  variable                         0
# Bp_bscale               double  variable                      0.01
# cparms_sg005            string  variable             compress Rice
# Bt_bzero                double  variable                         0
# Bt_bscale               double  variable                      0.01
# cparms_sg006            string  variable             compress Rice
# Br_bzero                double  variable                         0
# Br_bscale               double  variable                      0.01
# cparms_sg007            string  variable             compress Rice
# Bp_err_bzero            double  variable                         0
# Bp_err_bscale           double  variable                     0.001
# cparms_sg008            string  variable             compress Rice
# Bt_err_bzero            double  variable                         0
# Bt_err_bscale           double  variable                     0.001
# cparms_sg009            string  variable             compress Rice
# Br_err_bzero            double  variable                         0
# Br_err_bscale           double  variable                     0.001
# cparms_sg010            string  variable             compress Rice
# conf_disambig_bzero     double  variable                         0
# conf_disambig_bscale    double  variable                         1
# DATE                      time  variable     -4712.01.01_11:59:28Z
# DATE_S                    time  variable     -4712.01.01_11:59:28Z
# DATE_B                    time  variable     -4712.01.01_11:59:28Z
# DATE__OBS                 time  variable  -4712.01.01_11:59:28.00Z
# DATE-OBS                  time  variable  -4712.01.01_11:59:28.00Z
# T_OBS                     time  variable  -4712.01.01_11:59:28_TAI
# T_REC                     time     ts_eq  -4712.01.01_11:59:28_TAI
# T_REC_epoch               time  constant   1993.01.01_00:00:00_TAI
# T_REC_step               float  constant                     720.0
# T_REC_unit              string  constant                      secs
# CADENCE                  float  constant                     720.0
# USFLUX                   float  variable                       nan
# MEANGAM                  float  variable                       nan
# MEANGBT                  float  variable                       nan
# MEANGBZ                  float  variable                       nan
# MEANGBH                  float  variable                       nan
# MEANJZD                  float  variable                       nan
# TOTUSJZ                  float  variable                       nan
# MEANALP                  float  variable                       nan
# MEANJZH                  float  variable                       nan
# TOTUSJH                  float  variable                       nan
# ABSNJZH                  float  variable                       nan
# SAVNCPP                  float  variable                       nan
# MEANPOT                  float  variable                       nan
# TOTPOT                   float  variable                       nan
# MEANSHR                  float  variable                       nan
# SHRGT45                  float  variable                       nan
# R_VALUE                  float  variable                       nan
# GWILL                    float  variable                       nan
# CTYPE1                  string  constant                  CRLN-CEA
# CTYPE2                  string  constant                  CRLT-CEA
# CRPIX1                   float  variable                       nan
# CRPIX2                   float  variable                       nan
# CRVAL1                   float  variable                  0.000000
# CRVAL2                   float  variable                  0.000000
# CDELT1                   float  variable                       nan
# CDELT2                   float  variable                       nan
# CUNIT1                  string  constant                    degree
# CUNIT2                  string  constant                    degree
# IMCRPIX1                 float  variable                       nan
# IMCRPIX2                 float  variable                       nan
# IMCRVAL1                 float  variable                  0.000000
# IMCRVAL2                 float  variable                  0.000000
# CROTA2                   float  variable                       nan
# CRDER1                   float  variable                       nan
# CRDER2                   float  variable                       nan
# CSYSER1                  float  variable                       nan
# CSYSER2                  float  variable                       nan
# WCSNAME                 string  constant   Carrington Heliographic
# DSUN_OBS                double  variable                       nan
# DSUN_REF                double  constant              149597870691
# RSUN_REF                double  constant                 696000000
# CRLN_OBS                 float  variable                       nan
# CRLT_OBS                 float  variable                       nan
# CAR_ROT                    int  variable               -2147483648
# OBS_VR                  double  variable                       nan
# OBS_VW                  double  variable                       nan
# OBS_VN                  double  variable                       nan
# RSUN_OBS                double  variable                       nan
# TELESCOP                string  constant                   SDO/HMI
# INSTRUME                string  variable
# WAVELNTH                 float  constant                    6173.0
# CAMERA                     int  variable               -2147483648
# QUALITY                    int  variable                0x80000000
# QUAL_S                     int  variable                0x80000000
# QUALLEV1                   int  variable                0x80000000
# BUNIT                   string   segment
# ORIGIN                  string  constant              SDO/JSOC-SDP
# CONTENT                 string  constant            HMI observable
# HISTORY                 string  variable
# COMMENT                 string  variable
# BLD_VERS                string  variable
# CALVER64              longlong  variable        0x0000000000000000
# CODEVER7                string  variable                     Blank
# HFLID                      int  variable               -2147483648
# HCFTID                     int  variable               -2147483648
# QLOOK                      int  constant                         0
# HARPNUM                    int  variable               -2147483648
# MASK                       int  variable                        64
# ARM_QUAL                   int  variable                0x80000000
# ARM_NCLN                   int  variable               -2147483648
# H_MERGE                    int  variable                         0
# H_FAINT                    int  variable                         0
# ARM_MODL                string  variable
# ARM_EDGE                 float  variable                       nan
# ARM_BETA                string  variable
# LATDTMIN                 float  variable                       nan
# LONDTMIN                 float  variable                       nan
# LATDTMAX                 float  variable                       nan
# LONDTMAX                 float  variable                       nan
# OMEGA_DT                 float  variable                       nan
# NPIX                       int  variable               -2147483648
# SIZE                     float  variable                       nan
# AREA                     float  variable                       nan
# NACR                       int  variable               -2147483648
# SIZE_ACR                 float  variable                       nan
# AREA_ACR                 float  variable                       nan
# MTOT                     float  variable                       nan
# MNET                     float  variable                       nan
# MPOS_TOT                 float  variable                       nan
# MNEG_TOT                 float  variable                       nan
# MMEAN                    float  variable                       nan
# MSTDEV                   float  variable                       nan
# MSKEW                    float  variable                       nan
# MKURT                    float  variable                       nan
# LAT_MIN                  float  variable                       nan
# LON_MIN                  float  variable                       nan
# LAT_MAX                  float  variable                       nan
# LON_MAX                  float  variable                       nan
# LAT_FWT                  float  variable                       nan
# LON_FWT                  float  variable                       nan
# LAT_FWTPOS               float  variable                       nan
# LON_FWTPOS               float  variable                       nan
# LAT_FWTNEG               float  variable                       nan
# LON_FWTNEG               float  variable                       nan
# T_FRST                    time  variable  -4712.01.01_11:59:28_TAI
# T_FRST1                   time  variable  -4712.01.01_11:59:28_TAI
# T_LAST1                   time  variable  -4712.01.01_11:59:28_TAI
# T_LAST                    time  variable  -4712.01.01_11:59:28_TAI
# N_PATCH                    int  variable               -2147483648
# N_PATCH1                   int  variable               -2147483648
# N_PATCHM                   int  variable               -2147483648
# NOAA_AR                    int  variable               -2147483648
# NOAA_NUM                   int  variable               -2147483648
# NOAA_ARS                string  variable
# INVCODEV                string  variable
# INVDOCU                 string  variable
# INVITERA                   int  variable                        -1
# INVSTLGT                string  variable
# INVFLPRF                string  variable
# INVPHMAP                string  variable
# INVVLAVE                double  variable                       nan
# INVBLAVE                double  variable                       nan
# INVBBAVE                double  variable                       nan
# INVNPRCS                   int  variable                        -1
# INVNCNVG                   int  variable                        -1
# AMBCODEV                string  variable
# AMBDOCU                 string  variable
# AMBGMTRY                   int  variable               -2147483648
# AMBPATCH                   int  variable               -2147483648
# AMBWEAK                    int  variable               -2147483648
# AMBNEROD                   int  variable               -2147483648
# AMBNGROW                   int  variable               -2147483648
# AMBNPAD                    int  variable               -2147483648
# AMBNAP                     int  variable               -2147483648
# AMBNTX                     int  variable               -2147483648
# AMBNTY                     int  variable               -2147483648
# AMBBTHR0                double  variable                       nan
# AMBBTHR1                double  variable                       nan
# AMBSEED                    int  variable               -2147483648
# AMBNEQ                     int  variable               -2147483648
# AMBLMBDA                double  variable                       nan
# AMBTFCT0                double  variable                       nan
# AMBTFCTR                double  variable                       nan
# DATAVALS                   int   segment               -2147483648
# MISSVALS                   int   segment               -2147483648
# DATAMIN                  float   segment                       nan
# DATAMAX                  float   segment                       nan
# DATAMEDN                 float   segment                       nan
# DATAMEAN                 float   segment                       nan
# DATARMS                  float   segment                       nan
# T_REC_index           longlong     index                         0
# ERRGAM                   float  variable                       nan
# ERRTAI                   float  variable                       nan
# ERRBH                    float  variable                       nan
# ERRMPOT                  float  variable                       nan
# ERRBT                    float  variable                       nan
# ERRTUI                   float  variable                       nan
# ERRBZ                    float  variable                       nan
# CMASK                    float  variable                       nan
# ERRJZ                    float  variable                       nan
# ERRVF                    float  variable                       nan
# ERRALP                   float  variable                       nan
# ERRMIH                   float  variable                       nan
# ERRMSHA                  float  variable                       nan
# ERRUSI                   float  variable                       nan
# DOFFSET                    int  variable               -2147483648
# ERRTPOT                  float  variable                       nan
# ERRJHT                   float  variable                       nan
#
#                                           units  \
# name
# cparms_sg000                               none
# magnetogram_bzero                          none
# magnetogram_bscale                         none
# cparms_sg001                               none
# bitmap_bzero                               none
# bitmap_bscale                              none
# cparms_sg002                               none
# Dopplergram_bzero                          none
# Dopplergram_bscale                         none
# cparms_sg003                               none
# continuum_bzero                            none
# continuum_bscale                           none
# cparms_sg004                               none
# Bp_bzero                                   none
# Bp_bscale                                  none
# cparms_sg005                               none
# Bt_bzero                                   none
# Bt_bscale                                  none
# cparms_sg006                               none
# Br_bzero                                   none
# Br_bscale                                  none
# cparms_sg007                               none
# Bp_err_bzero                               none
# Bp_err_bscale                              none
# cparms_sg008                               none
# Bt_err_bzero                               none
# Bt_err_bscale                              none
# cparms_sg009                               none
# Br_err_bzero                               none
# Br_err_bscale                              none
# cparms_sg010                               none
# conf_disambig_bzero                        none
# conf_disambig_bscale                       none
# DATE                                        ISO
# DATE_S                                      ISO
# DATE_B                                      ISO
# DATE__OBS                                   ISO
# DATE-OBS                                    ISO
# T_OBS                                       TAI
# T_REC                                       TAI
# T_REC_epoch                                 TAI
# T_REC_step                              seconds
# T_REC_unit                                 none
# CADENCE                                 seconds
# USFLUX                                  Maxwell
# MEANGAM                                 Degrees
# MEANGBT                                Gauss/Mm
# MEANGBZ                                Gauss/Mm
# MEANGBH                                Gauss/Mm
# MEANJZD                                mA/(m^2)
# TOTUSJZ                                 Amperes
# MEANALP                                    1/Mm
# MEANJZH                                 (G^2)/m
# TOTUSJH                                 (G^2)/m
# ABSNJZH                                 (G^2)/m
# SAVNCPP                                 Amperes
# MEANPOT               Ergs per cubic centimeter
# TOTPOT                Ergs per cubic centimeter
# MEANSHR                                 Degrees
# SHRGT45                     Percentage of Total
# R_VALUE                                 Maxwell
# GWILL                                        Mm
# CTYPE1                                     none
# CTYPE2                                     none
# CRPIX1                                    pixel
# CRPIX2                                    pixel
# CRVAL1                                   degree
# CRVAL2                                   degree
# CDELT1                                   degree
# CDELT2                                   degree
# CUNIT1                                     none
# CUNIT2                                     none
# IMCRPIX1                                  pixel
# IMCRPIX2                                  pixel
# IMCRVAL1                                 arcsec
# IMCRVAL2                                 arcsec
# CROTA2                                      deg
# CRDER1                                   arcsec
# CRDER2                                   arcsec
# CSYSER1                                  arcsec
# CSYSER2                                  arcsec
# WCSNAME                                    none
# DSUN_OBS                                 meters
# DSUN_REF                                 meters
# RSUN_REF                                      m
# CRLN_OBS                                    deg
# CRLT_OBS                                    deg
# CAR_ROT                                    none
# OBS_VR                                      m/s
# OBS_VW                                      m/s
# OBS_VN                                      m/s
# RSUN_OBS                                 arcsec
# TELESCOP                                   none
# INSTRUME                                   none
# WAVELNTH                               Angstrom
# CAMERA                                     none
# QUALITY                                    none
# QUAL_S                                     none
# QUALLEV1                                   none
# BUNIT                                      none
# ORIGIN                                     none
# CONTENT                                    none
# HISTORY                                    none
# COMMENT                                    none
# BLD_VERS                                   none
# CALVER64                                   none
# CODEVER7                                   none
# HFLID                                      none
# HCFTID                                     none
# QLOOK                                      none
# HARPNUM                                    none
# MASK                                       none
# ARM_QUAL                                   none
# ARM_NCLN                                   none
# H_MERGE                                    none
# H_FAINT                                    none
# ARM_MODL                                   none
# ARM_EDGE                                   none
# ARM_BETA                                   none
# LATDTMIN                                 degree
# LONDTMIN                                 degree
# LATDTMAX                                 degree
# LONDTMAX                                 degree
# OMEGA_DT                             degree/day
# NPIX                                       none
# SIZE                                         mH
# AREA                                         mH
# NACR                                       none
# SIZE_ACR                                     mH
# AREA_ACR                                     mH
# MTOT                                      weber
# MNET                                      weber
# MPOS_TOT                                  weber
# MNEG_TOT                                  weber
# MMEAN                                     gauss
# MSTDEV                                    gauss
# MSKEW                                      none
# MKURT                                      none
# LAT_MIN                                  degree
# LON_MIN                                  degree
# LAT_MAX                                  degree
# LON_MAX                                  degree
# LAT_FWT                                  degree
# LON_FWT                                  degree
# LAT_FWTPOS                               degree
# LON_FWTPOS                               degree
# LAT_FWTNEG                               degree
# LON_FWTNEG                               degree
# T_FRST                                      TAI
# T_FRST1                                     TAI
# T_LAST1                                     TAI
# T_LAST                                      TAI
# N_PATCH                                    none
# N_PATCH1                                   none
# N_PATCHM                                   none
# NOAA_AR                                    none
# NOAA_NUM                                   none
# NOAA_ARS                                   none
# INVCODEV                                   none
# INVDOCU                                    none
# INVITERA                                   none
# INVSTLGT                                   none
# INVFLPRF                                   none
# INVPHMAP                                   none
# INVVLAVE                                Maxwell
# INVBLAVE                               Gauss/Mm
# INVBBAVE                                  gauss
# INVNPRCS                                 number
# INVNCNVG                                   none
# AMBCODEV                                   none
# AMBDOCU                                    none
# AMBGMTRY                                   none
# AMBPATCH                                   none
# AMBWEAK                                    none
# AMBNEROD                                 pixels
# AMBNGROW                                 pixels
# AMBNPAD                                  pixels
# AMBNAP                                   pixels
# AMBNTX                                     none
# AMBNTY                                     none
# AMBBTHR0                                      G
# AMBBTHR1                                      G
# AMBSEED                                    none
# AMBNEQ                                     none
# AMBLMBDA                                   none
# AMBTFCT0                                   none
# AMBTFCTR                                   none
# DATAVALS                                   none
# MISSVALS                                   none
# DATAMIN                                    none
# DATAMAX                                    none
# DATAMEDN                                   none
# DATAMEAN                                   none
# DATARMS                                    none
# T_REC_index                                none
# ERRGAM                                  Degrees
# ERRTAI                                  (G^2)/m
# ERRBH                                  Gauss/Mm
# ERRMPOT               Ergs per cubic centimeter
# ERRBT                                  Gauss/Mm
# ERRTUI                                  (G^2)/m
# ERRBZ                                  Gauss/Mm
# CMASK                                    number
# ERRJZ                                  mA/(m^2)
# ERRVF                                   Maxwell
# ERRALP                                     1/Mm
# ERRMIH                                  (G^2)/m
# ERRMSHA                                 Degrees
# ERRUSI                                  Amperes
# DOFFSET                                   Gauss
# ERRTPOT               Ergs per cubic centimeter
# ERRJHT                                  Amperes
#
#                                                                                                       note  \
# name
# cparms_sg000
# magnetogram_bzero
# magnetogram_bscale
# cparms_sg001
# bitmap_bzero
# bitmap_bscale
# cparms_sg002
# Dopplergram_bzero
# Dopplergram_bscale
# cparms_sg003
# continuum_bzero
# continuum_bscale
# cparms_sg004
# Bp_bzero
# Bp_bscale
# cparms_sg005
# Bt_bzero
# Bt_bscale
# cparms_sg006
# Br_bzero
# Br_bscale
# cparms_sg007
# Bp_err_bzero
# Bp_err_bscale
# cparms_sg008
# Bt_err_bzero
# Bt_err_bscale
# cparms_sg009
# Br_err_bzero
# Br_err_bscale
# cparms_sg010
# conf_disambig_bzero
# conf_disambig_bscale
# DATE                                                          Time that the SHARP keywords were calculated
# DATE_S                                                                 Date_time of generating Stokes data
# DATE_B                                                                  Date_time of generating Bharp data
# DATE__OBS                                                        [DATE-OBS] DATE_OBS = T_OBS - EXPTIME/2.0
# DATE-OBS                                                         [DATE-OBS] DATE_OBS = T_OBS - EXPTIME/2.0
# T_OBS                                                                                         nominal time
# T_REC                                                                                            Slot time
# T_REC_epoch                                                                                 Time of origin
# T_REC_step                                                                                      ts_eq step
# T_REC_unit                                                                                      ts_eq unit
# CADENCE                                                                                repetition interval
# USFLUX                                                                                 Total unsigned flux
# MEANGAM                                                                      Mean inclination angle, gamma
# MEANGBT                                                             Mean value of the total field gradient
# MEANGBZ                                                          Mean value of the vertical field gradient
# MEANGBH                                                        Mean value of the horizontal field gradient
# MEANJZD                                                                      Mean vertical current density
# TOTUSJZ                                                                    Total unsigned vertical current
# MEANALP                                                                        Mean twist parameter, alpha
# MEANJZH                                                                              Mean current helicity
# TOTUSJH                                                                    Total unsigned current helicity
# ABSNJZH                                                         Absolute value of the net current helicity
# SAVNCPP                               Sum of the Absolute Value of the Net Currents Per Polarity (SAVNCPP)
# MEANPOT                                                   Mean photospheric excess magnetic energy density
# TOTPOT                                                          Total photospheric magnetic energy density
# MEANSHR                                                                       Mean shear angle for B_total
# SHRGT45                                   Area with shear angle greater than 45 as a percent of total area
# R_VALUE                                                                  Unsigned Flux R (Schrijver, 2007)
# GWILL                                                                       GWILL (Mason & Hoeksema, 2010)
# CTYPE1                                                                                            CRLN-CEA
# CTYPE2                                                                                            CRLT-CEA
# CRPIX1                          X coordinate of patch center with respect to lower-left corner (in pixels)
# CRPIX2                          Y coordinate of patch center with respect to lower-left corner (in pixels)
# CRVAL1                                                                        Longitude at center of patch
# CRVAL2                                                                         Latitude at center of patch
# CDELT1                                                                            Map scale in X direction
# CDELT2                                                                            Map scale in Y direction
# CUNIT1                                                                                              Degree
# CUNIT2                                                                                              Degree
# IMCRPIX1                                                     Location of the Sun center in CCD x direction
# IMCRPIX2                                                     Location of the Sun center in CCD y direction
# IMCRVAL1                                                               x origin - center of the solar disk
# IMCRVAL2                                                               y origin - center of the solar disk
# CROTA2                                                                          CROTA2: INST_ROT + SAT_ROT
# CRDER1                                                    CRDER1: estimate of random error in coordinate x
# CRDER2                                                    CRDER2: estimate of random error in coordinate y
# CSYSER1                                              CSYSER1: estimate of systematic error in coordinate x
# CSYSER2                                              CSYSER2: estimate of systematic error in coordinate y
# WCSNAME                                                                                    WCS system name
# DSUN_OBS                                                                  Distance from SDO to Sun center.
# DSUN_REF                                                                                 Astronomical Unit
# RSUN_REF                                                      Reference radius of the Sun: 696,000,000.0 m
# CRLN_OBS                                                              Carrington longitude of the observer
# CRLT_OBS                                                               Carrington latitude of the observer
# CAR_ROT                                                             Carrington rotation number of CRLN_OBS
# OBS_VR                                    velocity of the observer in radial direction. + is away from Sun
# OBS_VW                        velocity of the observer solar-westward. + in rough direction of Earth orbit
# OBS_VN                                 velocity of the observer solar-northward (heliographic). + to north
# RSUN_OBS                                   angular radius of Sun. Corresponds to arcsin(RSUN_REF/DSUN_OBS)
# TELESCOP                                                                                  For HMI: SDO/HMI
# INSTRUME                                                   For HMI: HMI_SIDE1, HMI_FRONT2, or HMI_COMBINED
# WAVELNTH                                                                         For HMI: 6173.3 Angstroms
# CAMERA                                     For HMI: 1 (side camera), 2 (front camera), or 3 (both cameras)
# QUALITY                                                                                SHARP Quality index
# QUAL_S                                                                               Level 1p Quality word
# QUALLEV1                                                Logical OR on the bits of the level 1 Quality word
# BUNIT                                                           BUNIT: physical units of each data segment
# ORIGIN                                                                    ORIGIN: location where file made
# CONTENT                                                                                            CONTENT
# HISTORY                                                                                    history of data
# COMMENT                                                                             commentary on the data
# BLD_VERS                                                                         JSOC-build version number
# CALVER64                                                                               Calibration Version
# CODEVER7                                                                       CVS Version of sharp module
# HFLID                                                                                 HMI_SEQ_ID_FRAMELIST
# HCFTID                                                                                    HMI_SEQ_ID_FOCUS
# QLOOK                                                               QLOOK: 0=final data, 1=quick-look data
# HARPNUM                                                                                            HARP ID
# MASK                                                          Lower threshold for membership in this patch
# ARM_QUAL                                                                    Quality of the mask (bitfield)
# ARM_NCLN                                     Number of limb pixels reset to quiet (annulus width ARM_EDGE)
# H_MERGE                                         1 if this HARP merged with an existing region at this time
# H_FAINT                                                     1 if this HARP had faint contrast at this time
# ARM_MODL                                                       ARmask parameter: Classification model name
# ARM_EDGE                             ARmask parameter: Width of annulus at limb to possibly reset (pixels)
# ARM_BETA                                                         ARmask parameter: Mask spatial smoothness
# LATDTMIN                                                                 Minimum latitude for disk transit
# LONDTMIN                                                                Minimum longitude for disk transit
# LATDTMAX                                                                 Maximum latitude for disk transit
# LONDTMAX                                                                Maximum longitude for disk transit
# OMEGA_DT                                                                   Rotation rate over disk transit
# NPIX                                                                     Number of pixels within the patch
# SIZE                                                  Projected area of patch on image in micro-hemisphere
# AREA                                              De-projected area of patch on sphere in micro-hemisphere
# NACR                                                                      Number of active pixels in patch
# SIZE_ACR                                      Projected area of active pixels on image in micro-hemisphere
# AREA_ACR                                  De-projected area of active pixels on sphere in micro-hemisphere
# MTOT                                                 Sum of absolute LoS flux within the identified region
# MNET                                                             Net LoS flux within the identified region
# MPOS_TOT                                                         Absolute value of total positive LoS flux
# MNEG_TOT                                                         Absolute value of total negative LoS flux
# MMEAN                                                                             Mean of LoS flux density
# MSTDEV                                                              Standard deviation of LoS flux density
# MSKEW                                                                         Skewness of LoS flux density
# MKURT                                                                         Kurtosis of LoS flux density
# LAT_MIN                                             Minimum Stonyhurst latitude of pixels within the patch
# LON_MIN                                            Minimum Stonyhurst longitude of pixels within the patch
# LAT_MAX                                             Maximum Stonyhurst latitude of pixels within the patch
# LON_MAX                                            Maximum Stonyhurst longitude of pixels within the patch
# LAT_FWT                                       Stonyhurst latitude of flux-weighted center of active pixels
# LON_FWT                                      Stonyhurst longitude of flux-weighted center of active pixels
# LAT_FWTPOS                                    Stonyhurst latitude of flux-weighted center of positive flux
# LON_FWTPOS                                   Stonyhurst longitude of flux-weighted center of positive flux
# LAT_FWTNEG                                    Stonyhurst latitude of flux-weighted center of negative flux
# LON_FWTNEG                                   Stonyhurst longitude of flux-weighted center of negative flux
# T_FRST                                                 First T_REC stored for HARP (includes temporal pad)
# T_FRST1                                                                    T_REC of initial HARP detection
# T_LAST1                                                                      T_REC of final HARP detection
# T_LAST                                                  Last T_REC stored for HARP (includes temporal pad)
# N_PATCH                                                         Image slots spanned by HARP (includes pad)
# N_PATCH1                                                        Image slots spanned by HARP (excludes pad)
# N_PATCHM                                                    Missing images/slots in unpadded HARP interval
# NOAA_AR                                                         NOAA AR number that best matches this HARP
# NOAA_NUM                                               Number of NOAA ARs that match this HARP (0 allowed)
# NOAA_ARS                                               Comma-separated list of NOAA ARs matching this HARP
# INVCODEV                                                                             Version of VFISV code
# INVDOCU                                                                            Document for VFISV code
# INVITERA                                                                     Number of iterations of VFISV
# INVSTLGT                         Flag for stray light. No means that the stray light is not accounted for.
# INVFLPRF                                                                    Flag/Comment on filter-profile
# INVPHMAP                                                                         Flag/Comment on phase map
# INVVLAVE                                                                     [USFLUXL] Total unsigned flux
# INVBLAVE                                          [MEANGBL] Mean value of the line-of-sight field gradient
# INVBBAVE                                          avarage of inverted field strength over processed pixels
# INVNPRCS              [CMASKL] Number of pixels that contributed to the calculation of MEANGBL and USFLUXL
# INVNCNVG                                                       Numer of pixels at which ME VFISV converged
# AMBCODEV                                                                          Version of Disambig code
# AMBDOCU                                                                         Document for Disambig code
# AMBGMTRY                                      Flag determining whether to use planar or spherical geometry
# AMBPATCH              Flag determining whether disambiguation is done on a patch or full disk, 1 for patch
# AMBWEAK                                       Flag determining method for disambiguating weak field pixels
# AMBNEROD                                  Number of pixels by which to erode map of above threshold pixels
# AMBNGROW                                                      Number of pixels by which to grow eroded map
# AMBNPAD                                                      Padding to use in potential field calculation
# AMBNAP                                            Width of apodizing window in potential field calculation
# AMBNTX                               Number of tiles to use in x-direction for potential field calculation
# AMBNTY                               Number of tiles to use in y-direction for potential field calculation
# AMBBTHR0                  Transverse field strength threshold at disk center for using simulated annealing
# AMBBTHR1                         Transverse field strength threshold at limb for using simulated annealing
# AMBSEED                                                                           Input random number seed
# AMBNEQ                                    Number of reconfigurations attempted at each temperature setting
# AMBLMBDA                                  Weighting factor between divergence and vertical current density
# AMBTFCT0                                                         Input factor to scale initial temperature
# AMBTFCTR                                                                Input factor to reduce temperature
# DATAVALS                                                   Actual number of data values in images (pixels)
# MISSVALS                                                                                    Missing values
# DATAMIN                                               Minimum value from pixels within 99% of solar radius
# DATAMAX                                               Maximum value from pixels within 99% of solar radius
# DATAMEDN                                               Median value from pixels within 99% of solar radius
# DATAMEAN                                                 Mean value from pixels within 99% of solar radius
# DATARMS                             Rms deviation from the mean value of pixels within 99% of solar radius
# T_REC_index                                                            Index keyword associated with T_REC
# ERRGAM                                                              Error in Mean inclination angle, gamma
# ERRTAI                                                          Absolute value of the net current helicity
# ERRBH                                                 Error in Mean value of the horizontal field gradient
# ERRMPOT                                          Error in Mean photospheric excess magnetic energy density
# ERRBT                                                      Error in Mean value of the total field gradient
# ERRTUI                                                                     Total unsigned current helicity
# ERRBZ                                                   Error in Mean value of the vertical field gradient
# CMASK                                    Number of pixels that contributed to the spaceweather calculation
# ERRJZ                                                               Error in Mean vertical current density
# ERRVF                                                                         Error in Total unsigned flux
# ERRALP                                                                Error in Mean twist parameter, alpha
# ERRMIH                                                                               Mean current helicity
# ERRMSHA                                                              Error in Mean shear angle for B_total
# ERRUSI                                                            Error in Total unsigned vertical current
# DOFFSET                                         Constant value added to the noise mask for disambiguation.
# ERRTPOT                                                Error in Total photospheric magnetic energy density
# ERRJHT                                Sum of the Absolute Value of the Net Currents Per Polarity (SAVNCPP)
#
#                       is_time  is_integer  is_real  is_numeric
# name
# cparms_sg000            False       False    False       False
# magnetogram_bzero       False       False     True        True
# magnetogram_bscale      False       False     True        True
# cparms_sg001            False       False    False       False
# bitmap_bzero            False       False     True        True
# bitmap_bscale           False       False     True        True
# cparms_sg002            False       False    False       False
# Dopplergram_bzero       False       False     True        True
# Dopplergram_bscale      False       False     True        True
# cparms_sg003            False       False    False       False
# continuum_bzero         False       False     True        True
# continuum_bscale        False       False     True        True
# cparms_sg004            False       False    False       False
# Bp_bzero                False       False     True        True
# Bp_bscale               False       False     True        True
# cparms_sg005            False       False    False       False
# Bt_bzero                False       False     True        True
# Bt_bscale               False       False     True        True
# cparms_sg006            False       False    False       False
# Br_bzero                False       False     True        True
# Br_bscale               False       False     True        True
# cparms_sg007            False       False    False       False
# Bp_err_bzero            False       False     True        True
# Bp_err_bscale           False       False     True        True
# cparms_sg008            False       False    False       False
# Bt_err_bzero            False       False     True        True
# Bt_err_bscale           False       False     True        True
# cparms_sg009            False       False    False       False
# Br_err_bzero            False       False     True        True
# Br_err_bscale           False       False     True        True
# cparms_sg010            False       False    False       False
# conf_disambig_bzero     False       False     True        True
# conf_disambig_bscale    False       False     True        True
# DATE                     True       False    False       False
# DATE_S                   True       False    False       False
# DATE_B                   True       False    False       False
# DATE__OBS                True       False    False       False
# DATE-OBS                 True       False    False       False
# T_OBS                    True       False    False       False
# T_REC                    True       False    False       False
# T_REC_epoch              True       False    False       False
# T_REC_step              False       False     True        True
# T_REC_unit              False       False    False       False
# CADENCE                 False       False     True        True
# USFLUX                  False       False     True        True
# MEANGAM                 False       False     True        True
# MEANGBT                 False       False     True        True
# MEANGBZ                 False       False     True        True
# MEANGBH                 False       False     True        True
# MEANJZD                 False       False     True        True
# TOTUSJZ                 False       False     True        True
# MEANALP                 False       False     True        True
# MEANJZH                 False       False     True        True
# TOTUSJH                 False       False     True        True
# ABSNJZH                 False       False     True        True
# SAVNCPP                 False       False     True        True
# MEANPOT                 False       False     True        True
# TOTPOT                  False       False     True        True
# MEANSHR                 False       False     True        True
# SHRGT45                 False       False     True        True
# R_VALUE                 False       False     True        True
# GWILL                   False       False     True        True
# CTYPE1                  False       False    False       False
# CTYPE2                  False       False    False       False
# CRPIX1                  False       False     True        True
# CRPIX2                  False       False     True        True
# CRVAL1                  False       False     True        True
# CRVAL2                  False       False     True        True
# CDELT1                  False       False     True        True
# CDELT2                  False       False     True        True
# CUNIT1                  False       False    False       False
# CUNIT2                  False       False    False       False
# IMCRPIX1                False       False     True        True
# IMCRPIX2                False       False     True        True
# IMCRVAL1                False       False     True        True
# IMCRVAL2                False       False     True        True
# CROTA2                  False       False     True        True
# CRDER1                  False       False     True        True
# CRDER2                  False       False     True        True
# CSYSER1                 False       False     True        True
# CSYSER2                 False       False     True        True
# WCSNAME                 False       False    False       False
# DSUN_OBS                False       False     True        True
# DSUN_REF                False       False     True        True
# RSUN_REF                False       False     True        True
# CRLN_OBS                False       False     True        True
# CRLT_OBS                False       False     True        True
# CAR_ROT                 False        True    False        True
# OBS_VR                  False       False     True        True
# OBS_VW                  False       False     True        True
# OBS_VN                  False       False     True        True
# RSUN_OBS                False       False     True        True
# TELESCOP                False       False    False       False
# INSTRUME                False       False    False       False
# WAVELNTH                False       False     True        True
# CAMERA                  False        True    False        True
# QUALITY                 False        True    False        True
# QUAL_S                  False        True    False        True
# QUALLEV1                False        True    False        True
# BUNIT                   False       False    False       False
# ORIGIN                  False       False    False       False
# CONTENT                 False       False    False       False
# HISTORY                 False       False    False       False
# COMMENT                 False       False    False       False
# BLD_VERS                False       False    False       False
# CALVER64                False        True    False        True
# CODEVER7                False       False    False       False
# HFLID                   False        True    False        True
# HCFTID                  False        True    False        True
# QLOOK                   False        True    False        True
# HARPNUM                 False        True    False        True
# MASK                    False        True    False        True
# ARM_QUAL                False        True    False        True
# ARM_NCLN                False        True    False        True
# H_MERGE                 False        True    False        True
# H_FAINT                 False        True    False        True
# ARM_MODL                False       False    False       False
# ARM_EDGE                False       False     True        True
# ARM_BETA                False       False    False       False
# LATDTMIN                False       False     True        True
# LONDTMIN                False       False     True        True
# LATDTMAX                False       False     True        True
# LONDTMAX                False       False     True        True
# OMEGA_DT                False       False     True        True
# NPIX                    False        True    False        True
# SIZE                    False       False     True        True
# AREA                    False       False     True        True
# NACR                    False        True    False        True
# SIZE_ACR                False       False     True        True
# AREA_ACR                False       False     True        True
# MTOT                    False       False     True        True
# MNET                    False       False     True        True
# MPOS_TOT                False       False     True        True
# MNEG_TOT                False       False     True        True
# MMEAN                   False       False     True        True
# MSTDEV                  False       False     True        True
# MSKEW                   False       False     True        True
# MKURT                   False       False     True        True
# LAT_MIN                 False       False     True        True
# LON_MIN                 False       False     True        True
# LAT_MAX                 False       False     True        True
# LON_MAX                 False       False     True        True
# LAT_FWT                 False       False     True        True
# LON_FWT                 False       False     True        True
# LAT_FWTPOS              False       False     True        True
# LON_FWTPOS              False       False     True        True
# LAT_FWTNEG              False       False     True        True
# LON_FWTNEG              False       False     True        True
# T_FRST                   True       False    False       False
# T_FRST1                  True       False    False       False
# T_LAST1                  True       False    False       False
# T_LAST                   True       False    False       False
# N_PATCH                 False        True    False        True
# N_PATCH1                False        True    False        True
# N_PATCHM                False        True    False        True
# NOAA_AR                 False        True    False        True
# NOAA_NUM                False        True    False        True
# NOAA_ARS                False       False    False       False
# INVCODEV                False       False    False       False
# INVDOCU                 False       False    False       False
# INVITERA                False        True    False        True
# INVSTLGT                False       False    False       False
# INVFLPRF                False       False    False       False
# INVPHMAP                False       False    False       False
# INVVLAVE                False       False     True        True
# INVBLAVE                False       False     True        True
# INVBBAVE                False       False     True        True
# INVNPRCS                False        True    False        True
# INVNCNVG                False        True    False        True
# AMBCODEV                False       False    False       False
# AMBDOCU                 False       False    False       False
# AMBGMTRY                False        True    False        True
# AMBPATCH                False        True    False        True
# AMBWEAK                 False        True    False        True
# AMBNEROD                False        True    False        True
# AMBNGROW                False        True    False        True
# AMBNPAD                 False        True    False        True
# AMBNAP                  False        True    False        True
# AMBNTX                  False        True    False        True
# AMBNTY                  False        True    False        True
# AMBBTHR0                False       False     True        True
# AMBBTHR1                False       False     True        True
# AMBSEED                 False        True    False        True
# AMBNEQ                  False        True    False        True
# AMBLMBDA                False       False     True        True
# AMBTFCT0                False       False     True        True
# AMBTFCTR                False       False     True        True
# DATAVALS                False        True    False        True
# MISSVALS                False        True    False        True
# DATAMIN                 False       False     True        True
# DATAMAX                 False       False     True        True
# DATAMEDN                False       False     True        True
# DATAMEAN                False       False     True        True
# DATARMS                 False       False     True        True
# T_REC_index             False        True    False        True
# ERRGAM                  False       False     True        True
# ERRTAI                  False       False     True        True
# ERRBH                   False       False     True        True
# ERRMPOT                 False       False     True        True
# ERRBT                   False       False     True        True
# ERRTUI                  False       False     True        True
# ERRBZ                   False       False     True        True
# CMASK                   False       False     True        True
# ERRJZ                   False       False     True        True
# ERRVF                   False       False     True        True
# ERRALP                  False       False     True        True
# ERRMIH                  False       False     True        True
# ERRMSHA                 False       False     True        True
# ERRUSI                  False       False     True        True
# DOFFSET                 False        True    False        True
# ERRTPOT                 False       False     True        True
# ERRJHT                  False       False     True        True

# %% [markdown]
# Based on the information above, we shall extract data for the following keywords:

# %%
keywords = [
    # SHARP parameters
    "USFLUX", "MEANGAM", "MEANGBT", "MEANGBZ", "MEANGBH", "MEANJZD", "TOTUSJZ", "MEANALP",
    "MEANJZH", "TOTUSJH", "ABSNJZH", "SAVNCPP", "MEANPOT", "TOTPOT", "MEANSHR", "SHRGT45",
    # Carrington quantities
    "CRLN_OBS", "CRLT_OBS", "CAR_ROT",
    # Data quality information
    "QUALITY", "QUAL_S", "QUALLEV1",
    # History and commentary
    "HISTORY", "COMMENT",
    # HARP merger and faintness indicators
    "H_MERGE", "H_FAINT",
    # Patch areas and pixel counts
    "NPIX", "SIZE", "AREA", "NACR", "SIZE_ACR", "AREA_ACR",
    # Patch latitudes and longitudes
    "LAT_MIN", "LON_MIN", "LAT_MAX", "LON_MAX", "LAT_FWT", "LON_FWT",
    "LAT_FWTPOS", "LON_FWTPOS", "LAT_FWTNEG", "LON_FWTNEG",
    # First and last HARP detection times
    "T_FRST1", "T_LAST1",
    # NOAA AR information
    "NOAA_AR", "NOAA_NUM", "NOAA_ARS"
]

# %% [markdown]
# We put the selected keywords in a file that the data downloading script will use.

# %%
with open("keywords.txt", "w") as file:
    for keyword in keywords:
        file.write(keyword + "\n")
